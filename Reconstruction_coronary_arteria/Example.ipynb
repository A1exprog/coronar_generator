# %%
import numpy as np
import json
from Transformation import TransformationMatrix
from Reconstruction import Reconstruction_methods
from Reconsruction_run import Reconstruction_run

# %%
file_path = "a.json"
data1 = json.load(open(file_path,'r'))
curves_pr1 = data1['projections/10.dcm']['Paths'][2]
radius_pr1 = data1['projections/10.dcm']['Radius'][2]
Positioner1PrimaryAngle=data1['projections/10.dcm']['PositionerPrimaryAngle']
Positioner1SecondaryAngle= data1['projections/10.dcm']['PositionerSecondaryAngle']

file_path = "b.json"
data2 = json.load(open(file_path,'r'))
curves_pr2 = data2['projections/7.dcm']['Paths'][2]
radius_pr2 = data2['projections/7.dcm']['Radius'][2]
Positioner2PrimaryAngle=data2['projections/7.dcm']['PositionerPrimaryAngle']
Positioner2SecondaryAngle= data2['projections/7.dcm']['PositionerSecondaryAngle']

angles1 = np.array([Positioner1PrimaryAngle,Positioner1SecondaryAngle])
angles2 =np.array([Positioner2PrimaryAngle,Positioner2SecondaryAngle])

# %%
#x,y,z,r
Reconstruction_run(curves_pr1,curves_pr2,radius_pr1,radius_pr2,angles1,angles2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 #x,y,z,r
# ----> 2 Reconstruction_run(curves_pr1,curves_pr2,radius_pr1,radius_pr2,angles1,angles2)
#
# File ~\coronary_reconstruction\Reconstruction_coronary_arteria\Reconsruction_run.py:10, in Reconstruction_run(curves_pr1, curves_pr2, radius_pr1, radius_pr2, angles1, angles2)
#       8 curve_pr2 = TransformationMatrix.tr_points(curves_pr2,0.22)
#       9 recon = Reconstruction_methods(curve_pr1,curve_pr2,radius_pr1,radius_pr2, angles1, angles2)
# ---> 10 recon.calibrate1()
#      11 recon.partial_matching()
#      12 recon.reconstruct_3d_curve()
#
# File ~\coronary_reconstruction\Reconstruction_coronary_arteria\Reconstruction.py:104, in Reconstruction_methods.calibrate1(self)
#     102 initial_guess = [0,0,0,0,0,0,0,0]
#     103 # Запускаем оптимизацию только для углов второй проекции
# ...
